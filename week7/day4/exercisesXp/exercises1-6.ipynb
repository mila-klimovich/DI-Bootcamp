# %% [markdown]
# Exercise 1: Identifying Data Types
#
# Below are various data sources. Identify whether each one is an example of structured or unstructured data.
#
# A company's financial reports stored in an Excel file. - Structured
#
# Photographs uploaded to a social media platform. - Unstructured
#
# A collection of news articles on a website. - Unstructured
#
# Inventory data in a relational database. - Structured
#
# Recorded interviews from a market research study. - Unstructured

# %% [markdown]
# Exercise 2: Transformation Exercise
#
# For each of the following unstructured data sources, propose a method to convert it into structured data. Explain your reasoning.
#
# A series of blog posts about travel experiences. - To convert it into structured data will extract key info like dates, location, rating etc and put in a structured table format.
#
# Audio recordings of customer service calls. - Convert audio into text, extract key info like duration, topic, keywords etc and put in a structured table format.
#
# Handwritten notes from a brainstorming session. - Convert handwriting into text, extract key info like author, keywords atc and put in a structured table format.
#
# A video tutorial on cooking. - Convert video to text, extrat key info, put in a structured table format.

# %%
from google.colab import files
files.upload()

# !unzip -q train.zip
# Out:
#      <input type="file" id="files-27bff49e-782a-4b04-bec5-f1853041cb73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27bff49e-782a-4b04-bec5-f1853041cb73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

train_data = pd.read_csv('train.csv')
train_data.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
files.upload()

# !unzip -q Iris.zip
# Out:
#      <input type="file" id="files-c74850f3-9a62-4255-a598-5b4d0778393e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c74850f3-9a62-4255-a598-5b4d0778393e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
iris_data = pd.read_csv('Iris Dataset/Iris.csv')
iris_data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dog_data = {
    'Breed': ['Labrador Retriever', 'German Shepherd', 'Golden Retriever', 'Bulldog', 'Beagle'],
    'Size': ['Large', 'Large', 'Large', 'Medium', 'Small'],
    'Country': ['Canada', 'Germany', 'Scotland', 'England', 'England']
}

dogs_df = pd.DataFrame(dog_data)
dogs_df
# Out:
#                 Breed    Size   Country
# 0  Labrador Retriever   Large    Canada
# 1     German Shepherd   Large   Germany
# 2    Golden Retriever   Large  Scotland
# 3             Bulldog  Medium   England
# 4              Beagle   Small   England

# %%
dogs_df.to_excel('dog_breeds.xlsx', sheet_name='bark')

# %%
dogs_df.to_json('dog_breeds.json', orient='records', lines=True)

# %%
files.upload()

# !unzip -q posts.zip
# Out:
#      <input type="file" id="files-96663279-45c8-40c1-beeb-22cfbc1f276a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96663279-45c8-40c1-beeb-22cfbc1f276a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
json_data = pd.read_json('posts.json')
print(json_data.head())
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
