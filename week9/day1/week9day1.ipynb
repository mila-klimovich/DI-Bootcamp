# %%
import pandas as pd

# Sample data
data = {
    'Country': ['USA', 'USA', 'Canada', 'Canada'],
    'City': ['New York', 'Los Angeles', 'Toronto', 'Vancouver'],
    'Population': [8419000, 3971000, 2930000, 675218]
}

df = pd.DataFrame(data)
df.set_index(['Country', 'City'], inplace=True)
print(df)
# Out:
#                      Population
# Country City
# USA     New York        8419000
#         Los Angeles     3971000
# Canada  Toronto         2930000
#         Vancouver        675218

# %%
usa_df = df.loc['USA']
usa_df
# Out:
#              Population
# City
# New York        8419000
# Los Angeles     3971000

# %%
filtered_df = df[df['Population'] > 3000000]
print(filtered_df)
# Out:
#                      Population
# Country City
# USA     New York        8419000
#         Los Angeles     3971000

# %%
from google.colab import files
files.upload()

# !unzip -q WeatherData.zip
# Out:
#      <input type="file" id="files-53c074e0-620f-4071-ada5-6077ff60afe1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53c074e0-620f-4071-ada5-6077ff60afe1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

weather = pd.read_csv('weather_data.csv')
weather.head(6)
# Out:
#        Location            Date_Time  Temperature_C  Humidity_pct  \
# 0     San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1     San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2     San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3  Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4   San Antonio  2024-04-29 13:23:51      39.808213     72.899908
# 5     San Diego  2024-01-21 08:54:56      27.341055     49.023236
#
#    Precipitation_mm  Wind_Speed_kmh
# 0          4.020119        8.233540
# 1          9.111623       27.715161
# 2          4.607511       28.732951
# 3          3.183720       26.367303
# 4          9.598282       29.898622
# 5          9.166543       27.473896

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Location          1000000 non-null  object
#  1   Date_Time         1000000 non-null  object
#  2   Temperature_C     1000000 non-null  float64
#  3   Humidity_pct      1000000 non-null  float64
#  4   Precipitation_mm  1000000 non-null  float64
#  5   Wind_Speed_kmh    1000000 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 45.8+ MB

# %%
weather['Date_Time'] = pd.to_datetime(weather['Date_Time'])

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Location          1000000 non-null  object
#  1   Date_Time         1000000 non-null  datetime64[ns]
#  2   Temperature_C     1000000 non-null  float64
#  3   Humidity_pct      1000000 non-null  float64
#  4   Precipitation_mm  1000000 non-null  float64
#  5   Wind_Speed_kmh    1000000 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 45.8+ MB

# %%
weather.head(6)
# Out:
#        Location           Date_Time  Temperature_C  Humidity_pct  \
# 0     San Diego 2024-01-14 21:12:46      10.683001     41.195754
# 1     San Diego 2024-05-17 15:22:10       8.734140     58.319107
# 2     San Diego 2024-05-11 09:30:59      11.632436     38.820175
# 3  Philadelphia 2024-02-26 17:32:39      -8.628976     54.074474
# 4   San Antonio 2024-04-29 13:23:51      39.808213     72.899908
# 5     San Diego 2024-01-21 08:54:56      27.341055     49.023236
#
#    Precipitation_mm  Wind_Speed_kmh
# 0          4.020119        8.233540
# 1          9.111623       27.715161
# 2          4.607511       28.732951
# 3          3.183720       26.367303
# 4          9.598282       29.898622
# 5          9.166543       27.473896

# %%
df = pd.DataFrame(weather)
df.set_index(['Location', 'Date_Time'], inplace=True)
df
# Out:
#                                   Temperature_C  Humidity_pct  \
# Location     Date_Time
# San Diego    2024-01-14 21:12:46      10.683001     41.195754
#              2024-05-17 15:22:10       8.734140     58.319107
#              2024-05-11 09:30:59      11.632436     38.820175
# Philadelphia 2024-02-26 17:32:39      -8.628976     54.074474
# San Antonio  2024-04-29 13:23:51      39.808213     72.899908
# ...                                         ...           ...
# Dallas       2024-01-01 20:29:48      23.416877     37.705024
# San Antonio  2024-01-20 15:59:48       6.759080     40.731036
# New York     2024-04-14 08:30:09      15.664465     62.201884
# Chicago      2024-05-12 20:10:43      18.999994     63.703245
# New York     2024-04-16 16:11:52      10.725351     43.804584
#
#                                   Precipitation_mm  Wind_Speed_kmh
# Location     Date_Time
# San Diego    2024-01-14 21:12:46          4.020119        8.233540
# ...

# %%
df.reset_index(inplace=True)

filtered_df = df[(df['Location'] == 'San Diego') & (df['Temperature_C'] > 20)]

print(filtered_df)
# Out:
#         level_0   index   Location           Date_Time  Temperature_C  \
# 5             5       5  San Diego 2024-01-21 08:54:56      27.341055
# 20           20      20  San Diego 2024-01-25 12:59:32      33.023351
# 26           26      26  San Diego 2024-03-27 10:44:36      24.312724
# 44           44      44  San Diego 2024-03-03 11:02:14      35.666565
# 84           84      84  San Diego 2024-02-02 10:25:50      38.198558
# ...         ...     ...        ...                 ...            ...
# 999878   999878  999878  San Diego 2024-03-25 00:52:09      26.964128
# 999883   999883  999883  San Diego 2024-05-06 20:06:45      30.276787
# 999940   999940  999940  San Diego 2024-03-25 06:19:11      32.708046
# 999947   999947  999947  San Diego 2024-03-14 06:17:28      21.050270
# 999985   999985  999985  San Diego 2024-03-27 13:29:35      38.202771
#
#         Humidity_pct  Precipitation_mm  Wind_Speed_kmh
# 5          49.023236          9.166543       27.473896
# ...

# %%
data = {
    'Country': ['USA', 'USA', 'Canada', 'Canada'],
    'City': ['New York', 'Los Angeles', 'Toronto', 'Vancouver'],
    'Population': [8419000, 3971000, 2930000, 675218],
    'Date':['2023-07-01','2023-07-04', '2023-07-03', '2023-07-02'],
    'Temperature': [25, 31, 28, 21]
}

df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index(['Country', 'City', 'Date'], inplace=True)
print(df)
# Out:
#                                 Population  Temperature
# Country City        Date
# USA     New York    2023-07-01     8419000           25
#         Los Angeles 2023-07-04     3971000           31
# Canada  Toronto     2023-07-03     2930000           28
#         Vancouver   2023-07-02      675218           21

# %%
canada_df = df.loc['Canada']
canada_df
# Out:
#                       Population  Temperature
# City      Date
# Toronto   2023-07-03     2930000           28
# Vancouver 2023-07-02      675218           21

# %%
hot_days = canada_df[canada_df['Temperature'] >20]
print(hot_days)
# Out:
#                       Population  Temperature
# City      Date
# Toronto   2023-07-03     2930000           28
# Vancouver 2023-07-02      675218           21
